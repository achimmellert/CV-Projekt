# %%
import json

with open("class_labels.json", "r") as jf:
    label_indexer = {int(v): k for k, v in json.load(jf).items()}

# %%
label_indexer
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}
